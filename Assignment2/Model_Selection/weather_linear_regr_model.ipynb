# %% [markdown]
# **Assignment 2
# Model Implementation - Linear Regression**

# %% [markdown]
# Dataset 1 - Melbourne Olympic Park

# %% [markdown]
# Step 1 - Setup the environment by improting all the necessary libraries.

# %%
# Required Libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# Step 2 - Load the dataset

# %%
# Load Dataset 1
data1 = pd.read_csv('processed_melbourne_olympic.csv')
print(f'Melbourne Olympic Park Weather Data')
# View the first few rows of the dataset 1
data1.head()
# Out:
# Melbourne Olympic Park Weather Data
#                   time-local  maximum_gust_kmh  air_temperature  \
# 0  2018-01-01 07:00:00+00:00            0.4375         0.628125
# 1  2018-01-01 07:10:00+00:00            0.4375         0.621875
# 2  2018-01-01 07:20:00+00:00            0.4375         0.631250
# 3  2018-01-01 07:30:00+00:00            0.4375         0.615625
# 4  2018-01-01 07:40:00+00:00            0.4375         0.612500
#
#    maximum_gust_spd  msl_pres  minimum_air_temperature maximum_gust_dir  \
# 0           0.44186  0.320293                 0.623053              SSW
# 1           0.44186  0.569711                 0.616822              SSW
# 2           0.44186  0.569711                 0.610592              SSW
# 3           0.44186  0.325183                 0.610592              SSW
# 4           0.44186  0.569711                 0.610592              SSW
#
#    wind_dir_deg      pres  rainfall  ...  vis_km  wind_spd  wind_dir  \
# ...

# %% [markdown]
# Step 3 - Feature selection and Missing data handling

# %%
# Define independent (X) and dependent (y) variables
features = ['rel-humidity', 'wind_spd', 'msl_pres', 'rainfall']
X = data1[features]
y = data1['air_temperature'] # Temperature as the target

# Handle missing values
data = data1.dropna(subset=features + [y.name])

# %% [markdown]
# Step 4 - Splitting the data in to training and testing sets

# %%
# Train-test split
split_index = int(len(data1) * 0.8)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# %% [markdown]
# Step 5 - Training the Linear Regression model

# %%
# Train the Linear Regression Model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Step 6 - Making predictions and evaluate the model

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate model performance (Root Mean Square Error)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f'Root Mean Square Error: {rmse}')

# Evaluate model performance (r2_score)
r2 = r2_score(y_test, y_pred)
print(f'R-squared (R²): {r2}')
# Out:
# Root Mean Square Error: 0.1568232747816723
# R-squared (R²): -0.11260426469792262

# %% [markdown]
# Step 7 - Visualize the results

# %%
# plot actual vs predicted temperature
plt.figure(figsize=(14, 7))
plt.plot(y_test.values, label='Actual Temperature', color='blue')
plt.plot(y_pred, label='Predicted Temperature', color='red', linestyle='--')
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.title('Actual vs Predicted Temperature with Humdity, Wind-speed, Pressure and Rainfall (Location - Melbourne Olympic Park)')
plt.legend()
plt.show()

# %% [markdown]
# Dataset 2 - Cerberus

# %% [markdown]
# Step 1 - Load the dataset 2

# %%
# Load Dataset 2
data2 = pd.read_csv('processed_cerberus.csv')
print(f'Cerberus Weather Data')
# View the first few rows of the dataset 2
data2.head()
# Out:
# Cerberus Weather Data
#                   time-local  maximum_gust_kmh  air_temperature  msl_pres  \
# 0  2018-01-01 07:00:00+00:00          0.411765         0.648810  0.356295
# 1  2018-01-01 07:10:00+00:00          0.411765         0.654762  0.580456
# 2  2018-01-01 07:20:00+00:00          0.411765         0.648810  0.580456
# 3  2018-01-01 07:30:00+00:00          0.411765         0.645833  0.361045
# 4  2018-01-01 07:40:00+00:00          0.411765         0.642857  0.580456
#
#    minimum_air_temperature maximum_gust_dir  wind_dir_deg      pres  rainfall  \
# 0                 0.645833              SSW           200  0.356295       0.0
# 1                 0.645833              SSW           218  0.580456       0.0
# 2                 0.645833              SSW           217  0.580456       0.0
# 3                 0.645833              SSW           219  0.361045       0.0
# 4                 0.642857              SSW           201  0.580456       0.0
#
# ...

# %% [markdown]
# Step 2 - Feature selection and data handling

# %%
# Define independent (X) and dependent (y) variables
features2 = ['rel-humidity', 'wind_spd', 'msl_pres', 'rainfall']
X_new = data2[features2]
y_new = data2['air_temperature'] # Temperature as the target

# Handle missing values
data = data2.dropna(subset=features2 + [y_new.name])

# %% [markdown]
# Step 3 - Splitting the the datas in to training and testing sets

# %%
# Train-test split
split_index = int(len(data2) * 0.8)
X_new_train, X_new_test = X_new[:split_index], X_new[split_index:]
y_new_train, y_new_test = y_new[:split_index], y_new[split_index:]

# %% [markdown]
# Step 4 - Training the Linear Regression Model

# %%
model_new = LinearRegression()
model_new.fit(X_new_train, y_new_train)
# Out:
# LinearRegression()

# %% [markdown]
# Step 5 - Making predicvations and evaluating the model

# %%
# Make predictions on the test set
y_new_pred = model_new.predict(X_new_test)

# Evaluate model performance (Root Mean Square Error)
rmse_new = np.sqrt(mean_squared_error(y_new_test, y_new_pred))
print(f'Root Mean Square Error: {rmse_new}')

# Evaluate model performance (r2_score)
r2_new = r2_score(y_new_test, y_new_pred)
print(f'R-squared (R²): {r2_new}')
# Out:
# Root Mean Square Error: 0.1319098447222158
# R-squared (R²): -0.057323777326238945

# %% [markdown]
# Step 6 - Visualize the results

# %%
# Plot actual vs predicted temperature
plt.figure(figsize=(14, 7))
plt.plot(y_new_test.values, label='Actual Temperature (New Dataset)')
plt.plot(y_new_pred, label='Predicted Temperature (New Dataset)', linestyle='--')
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.title('Actual vs Predicted Temperature with Humdity, Wind-speed, Pressure and Rainfall (Location - Cerberus)')
plt.legend()
plt.show()
